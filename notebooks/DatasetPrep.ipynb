# %%
import os
import cv2
import numpy as np
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt

# Paths
polluted_path = r"C:\Users\shrad\OneDrive\Desktop\data\processed\polluted\Polluted\train"
clean_path = r"C:\Users\shrad\OneDrive\Desktop\data\processed\clean\train"

IMG_SIZE = (128, 128)  # Resize images

# %%
import os

base_path = r"C:\Users\shrad\OneDrive\Desktop\data\processed\polluted\Polluted"
print("📂 Contents of:", base_path)
print(os.listdir(base_path))
# Out:
# 📂 Contents of: C:\Users\shrad\OneDrive\Desktop\data\processed\polluted\Polluted
# ['README.dataset.txt', 'README.roboflow.txt', 'test', 'train']

# %%
import os

train_path = r"C:\Users\shrad\OneDrive\Desktop\data\processed\polluted\Polluted\train"
print("📁 Train folder contains:")
print(os.listdir(train_path))
# Out:
# 📁 Train folder contains:
# ...

# %%
img_folder = r"C:\Users\shrad\OneDrive\Desktop\data\processed\polluted\Polluted\train"

# %%
img_folder = r"C:\Users\shrad\OneDrive\Desktop\data\processed\polluted\Polluted\train"

# %%
import os
import cv2
import matplotlib.pyplot as plt

# Get all jpg files
images = [f for f in os.listdir(img_folder) if f.lower().endswith(('.jpg', '.jpeg', '.png'))]
print(f"Found {len(images)} images ✅")

# Display first image
if images:
    img_path = os.path.join(img_folder, images[0])
    img = cv2.imread(img_path)
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

    plt.imshow(img)
    plt.title(f"Sample: {images[0]}")
    plt.axis('off')
    plt.show()
else:
    print("⚠️ No images found in this folder.")
# Out:
# Found 69 images ✅

# %%
clean_folder = r"C:\Users\shrad\OneDrive\Desktop\data\processed\clean\train"

clean_imgs = [f for f in os.listdir(clean_folder) if f.lower().endswith(('.jpg', '.jpeg', '.png'))]
print(f"Found {len(clean_imgs)} clean images ✅")

if clean_imgs:
    img_path = os.path.join(clean_folder, clean_imgs[0])
    img = cv2.imread(img_path)
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

    plt.imshow(img)
    plt.title(f"Sample clean image: {clean_imgs[0]}")
    plt.axis('off')
    plt.show()
# Out:
# Found 20 clean images ✅

# %%
np.save('X_train.npy', X_train)
np.save('X_test.npy', X_test)
np.save('y_train.npy', y_train)
np.save('y_test.npy', y_test)
